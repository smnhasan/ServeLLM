# %% [markdown]
# # ServeLLM Server Notebook
#
# This notebook allows you to run the FastAPI server directly within the notebook environment.
# We use `nest_asyncio` to allow the Uvicorn event loop to run inside the Jupyter event loop.

# %%
import sys
import os

# Ensure the current directory is in the Python path so we can import 'app'
current_dir = os.path.abspath('')
if current_dir not in sys.path:
    sys.path.append(current_dir)

# Install nest_asyncio just in case it's missing
# !pip install -q nest_asyncio

# %%
import nest_asyncio
import uvicorn
from app.main import app

# Apply nest_asyncio to allow nested event loops in Jupyter
nest_asyncio.apply()

# Start the server
print("Starting the server on http://0.0.0.0:8000")
config = uvicorn.Config(app, host="0.0.0.0", port=8000)
server = uvicorn.Server(config)
await server.serve()
# Out:
# Starting the server on http://0.0.0.0:8000
# INFO:     Started server process [589910]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# [LLM Serve] Starting up — version 1.0.0
# [LLM Serve] Dummy mode: True
# [LLM Serve] Rate limiting: True (60 RPM)
# INFO:     127.0.0.1:53710 - "GET /docs HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53710 - "GET /openapi.json HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53710 - "GET /docs HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53710 - "GET /openapi.json HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53734 - "POST /v1/embeddings HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53734 - "GET /v1/models HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53734 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53734 - "POST /v1/completions HTTP/1.1" 200 OK
